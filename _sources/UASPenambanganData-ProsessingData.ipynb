# %% [markdown]
# **UAS Penambangan Data**
#
# Nama : Nurul Firdausy
#
# NIM : 160411100113

# %% [markdown]
# Deskripsi data :
#
# Sumber data : https://www.kaggle.com/datasets/tawfikelmetwally/automobile-dataset
#
# Type data : float
#
# Data tentang : stok mobil

# %% [markdown]
# **Prosessing Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
import seaborn as sns
import pickle

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **MIN MAX SCALAR**

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/nurulfirdausy/Penambangan-Data/gh-pages/Automobile.csv')
X = dataset.iloc[:,:4].values
y = dataset['origin'].values
dataset.head(5)
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
datairis="https://raw.githubusercontent.com/nurulfirdausy/Penambangan-Data/gh-pages/Automobile.csv"
iris=pd.read_csv(datairis)

# %%
iris.sample(150)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 359  peugeot 505s turbo diesel  28.1          4         141.0        80.0
# 396                ford ranger  28.0          4         120.0        79.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 308            pontiac phoenix  33.5          4         151.0        90.0
# 327        audi 5000s (diesel)  36.4          5         121.0        67.0
# ..                         ...   ...        ...           ...         ...
# 224    mercury cougar brougham  15.0          8         302.0       130.0
# 219          plymouth arrow gs  25.5          4         122.0        96.0
# 10         dodge challenger se  15.0          8         383.0       170.0
# 366     chrysler lebaron salon  17.6          6         225.0        85.0
# 48                ford mustang  18.0          6         250.0        88.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
iris_copy = iris.copy()
iris_copy.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
iris_copy = iris_copy.replace('?',np.nan)
iris_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# Get features and target
X = iris_copy[['cylinders',	'displacement',	'horsepower',	'weight',	'acceleration',	'model_year']]
y = iris_copy['origin']

# %%
iris['origin'].replace({'Iris-name':0, 'Iris-origin':1},inplace=True)

# %%
species_column = iris_copy['origin']
iris_copy = iris_copy[['cylinders',	'displacement',	'horsepower',	'weight',	'acceleration',	'model_year']].copy()
iris_copy = (iris_copy - iris_copy.min())/(iris_copy.max() - iris_copy.min())
iris_copy['origin'] = species_column.copy()
iris_copy.head(150)
data1 = iris.drop(columns=['origin'])
data1.head(150)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 145                 datsun 710  32.0          4          83.0        61.0
# 146                 dodge colt  28.0          4          90.0        75.0
# 147                   fiat 128  24.0          4          90.0        75.0
# 148                fiat 124 tc  26.0          4         116.0        75.0
# 149                honda civic  24.0          4         120.0        97.0
#
#      weight  acceleration  model_year
# 0      3504          12.0          70
# ...

# %% [markdown]
# **REDUKSI DIMENSI**

# %%
iris.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
iris.head(150)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 145                 datsun 710  32.0          4          83.0        61.0
# 146                 dodge colt  28.0          4          90.0        75.0
# 147                   fiat 128  24.0          4          90.0        75.0
# 148                fiat 124 tc  26.0          4         116.0        75.0
# 149                honda civic  24.0          4         120.0        97.0
#
#      weight  acceleration  model_year  origin
# ...
